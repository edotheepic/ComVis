# %% [markdown]
# <a href="https://colab.research.google.com/github/edotheepic/ComVis/blob/main/2440007226_ASSIGNMENT_01_COMP7116001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Eduardo Brilliandy
#
# NIM  : 2440007226

# %% [markdown]
# ####import libraries & image

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# !wget https://raw.githubusercontent.com/edotheepic/ComVis/main/image1.jpg
# Out:
# --2022-10-09 08:20:30--  https://raw.githubusercontent.com/edotheepic/ComVis/main/image1.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32900 (32K) [image/jpeg]
# Saving to: ‘image1.jpg.2’
#
# image1.jpg.2        100%[===================>]  32.13K  --.-KB/s    in 0s
#
# 2022-10-09 08:20:30 (89.5 MB/s) - ‘image1.jpg.2’ saved [32900/32900]

# %% [markdown]
# ####Convert image to grayscale & show image
#
# Image is converted to grayscale so we can manipulate the contrast.

# %%
img = cv.imread('image1.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# ####Show histogram of the image
#
# Since the histogram has small spread, the image has low contrast.

# %%
hist = cv.calcHist([img], [0], None, [256], [0,256])
plt.bar(range(256), hist.ravel())
plt.title('Histogram of low contrast image')
plt.xlabel('Gray values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ####Apply Histogram Equalization transformation to the image
#
# Histogram Equalization stretches the distribution of the gray-values of the image to enhance the contrast.

# %%
eq_img = cv.equalizeHist(img)
plt.imshow(eq_img, cmap='gray')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# ####Show the histogram of the equalized image
#
# The histogram is now spread more evenly, meaning the image now has better contrast.

# %%
eq_hist = cv.calcHist([eq_img], [0], None, [256], [0,256])
plt.bar(range(256),eq_hist.ravel())
plt.title('Histogram of image after histogram equalization')
plt.xlabel('Gray values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ####Show side by side comparison
#
# On the left side is the image & histogram before the transformation & the right side is after the transformation.

# %%
plt.figure(1, (10, 7))

plt.subplot(2, 2, 1)
plt.title('Before Equalization')
plt.imshow(img, cmap='gray')
plt.xticks([]), plt.yticks([])

plt.subplot(2, 2, 2)
plt.title('After Equalization')
plt.imshow(eq_img, cmap='gray')
plt.xticks([]), plt.yticks([])

plt.subplot(2, 2, 3)
plt.bar(range(256),hist.ravel())
plt.xlabel('Grey Values')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.bar(range(256),eq_hist.ravel())
plt.xlabel('Grey Values')
plt.ylabel('Frequency')

plt.show()
